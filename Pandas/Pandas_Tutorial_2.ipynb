# %% [markdown]
# <H1>Pandas Modülü Bölüm 2 - Detay Bilgiler</H1>

# %%
import pandas as pd

df = pd.read_csv("imdb_top_1000.csv")

df.head(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
# Dataframeimizin bir kopyasını copy() kullanarak oluşturabiliriz:

df_kopya = df.copy()
df_kopya.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %% [markdown]
# ### Column Drop

# %%
# Dataframeimizin bazı sütunları işimize yaramayabilir,
# bu sütunlardan nasıl kurtulabiliriz?

df_yeni = df.drop(['Certificate', 'Meta_score'], axis = 1)  # axis=1 ise column drop, 0 ise row drop eder. Default=0
df_yeni.head()
# Out:
#                Series_Title Released_Year  Runtime                 Genre  \
# 0  The Shawshank Redemption          1994  142 min                 Drama
# 1             The Godfather          1972  175 min          Crime, Drama
# 2           The Dark Knight          2008  152 min  Action, Crime, Drama
# 3    The Godfather: Part II          1974  202 min          Crime, Drama
# 4              12 Angry Men          1957   96 min          Crime, Drama
#
#    IMDB_Rating                                           Overview  \
# 0          9.3  Two imprisoned men bond over a number of years...
# 1          9.2  An organized crime dynasty's aging patriarch t...
# 2          9.0  When the menace known as the Joker wreaks havo...
# 3          9.0  The early life and career of Vito Corleone in ...
# 4          9.0  A jury holdout attempts to prevent a miscarria...
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
# Yukardaki aynı işlemi şu şekilde de yapabilirsiniz:
df_yeni2 = df.drop(columns = ['Certificate', 'Meta_score'])
df_yeni2.head()
# Out:
#                Series_Title Released_Year  Runtime                 Genre  \
# 0  The Shawshank Redemption          1994  142 min                 Drama
# 1             The Godfather          1972  175 min          Crime, Drama
# 2           The Dark Knight          2008  152 min  Action, Crime, Drama
# 3    The Godfather: Part II          1974  202 min          Crime, Drama
# 4              12 Angry Men          1957   96 min          Crime, Drama
#
#    IMDB_Rating                                           Overview  \
# 0          9.3  Two imprisoned men bond over a number of years...
# 1          9.2  An organized crime dynasty's aging patriarch t...
# 2          9.0  When the menace known as the Joker wreaks havo...
# 3          9.0  The early life and career of Vito Corleone in ...
# 4          9.0  A jury holdout attempts to prevent a miscarria...
#
#                Director           Star1           Star2          Star3  \
# ...

# %% [markdown]
# ### Row Drop

# %%
df_yeni3 = df.drop([0])
df_yeni3.head()
# Out:
#                                     Series_Title Released_Year Certificate  \
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
#
#    Runtime                     Genre  IMDB_Rating  \
# 1  175 min              Crime, Drama          9.2
# 2  152 min      Action, Crime, Drama          9.0
# 3  202 min              Crime, Drama          9.0
# 4   96 min              Crime, Drama          9.0
# 5  201 min  Action, Adventure, Drama          8.9
#
#                                             Overview  Meta_score  \
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# ...

# %% [markdown]
# ### Filtreleme

# %%
df_filtered = df[df['IMDB_Rating'] >= 9]

df_filtered
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
# veya...

df_filtered = df.query('IMDB_Rating >= 9')
df_filtered
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
f = lambda x: (x["Runtime"].split())[0] 
df["RuntimeYeni"] = df.apply(f, axis=1)

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# RuntimeYeni       object
# dtype: object

# %%
df['RuntimeYeni2'] = df['RuntimeYeni'].astype('int') 

df_filtered = df.query('RuntimeYeni2 >= 140')
df_filtered
# Out:
#                                       Series_Title Released_Year Certificate  \
# 0                         The Shawshank Redemption          1994           A
# 1                                    The Godfather          1972           A
# 2                                  The Dark Knight          2008          UA
# 3                           The Godfather: Part II          1974           A
# 5    The Lord of the Rings: The Return of the King          2003           U
# ..                                             ...           ...         ...
# 966                                      Apollo 13            PG           U
# 974                        The Godfather: Part III          1990           A
# 990                                   Giù la testa          1971          PG
# 991                                 Kelly's Heroes          1970          GP
# 996                                          Giant          1956           G
#
# ...

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# RuntimeYeni       object
# RuntimeYeni2       int32
# dtype: object

# %%
df = df.drop(['RuntimeYeni'], axis = 1)

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...
